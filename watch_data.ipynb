# %% [markdown]
# ML

# %%
import os, glob, pandas as pd

FEATURES_OUT = "data/features/ml/SBER/1m"
LABELS_OUT   = "data/labels/SBER/1m"

# 1) читаем фичи и лейблы
feat_pq = sorted(glob.glob(os.path.join(FEATURES_OUT, "*.parquet")))[0]
lab_pq  = sorted(glob.glob(os.path.join(LABELS_OUT,   "*.parquet")))[0]

dfX = pd.read_parquet(feat_pq)
dfY = pd.read_parquet(lab_pq)

# 2) унифицируем ключи
keys = [c for c in ["time","bar_id","date"] if c in dfX.columns and c in dfY.columns]
assert keys, "нет общих ключей для merge"

# 3) полный ML-датасет
ml = dfX.merge(dfY, on=keys, how="inner").sort_values(keys)
ml.info()
ml.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14835 entries, 0 to 14834
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           14835 non-null  datetime64[ns, UTC]
#  1   open_x         14835 non-null  float64
#  2   high_x         14835 non-null  float64
#  3   low_x          14835 non-null  float64
#  4   close_x        14835 non-null  float64
#  5   volume_x       14835 non-null  int64
#  6   ret_1_x        14834 non-null  float64
#  7   ret_5_x        14830 non-null  float64
#  8   rng_1_x        14834 non-null  float64
#  9   vol_20_x       14825 non-null  float64
#  10  vwap_20_x      14831 non-null  float64
#  11  dist_vwap_x    14831 non-null  float64
#  12  date           14835 non-null  object
#  13  bar_id         14835 non-null  int64
#  14  is_open_30_x   14835 non-null  int64
#  15  is_close_30_x  14835 non-null  int64
#  16  open_y         14835 non-null  float64
#  17  high_y         14835 non-null  float64
#  18  low_y          14835 non-null  float64
#  19  close_y        14835 non-null  float64
#  20  volume_y       14835 non-null  int64
#  21  ret_1_y        14834 non-null  float64
#  22  ret_5_y        14830 non-null  float64
#  23  rng_1_y        14834 non-null  float64
#  24  vol_20_y       14825 non-null  float64
#  25  vwap_20_y      14831 non-null  float64
#  26  dist_vwap_y    14831 non-null  float64
#  27  is_open_30_y   14835 non-null  int64
#  28  is_close_30_y  14835 non-null  int64
#  29  ret_fwd_5      14835 non-null  float64
#  30  y_tb_20        14835 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(21), int64(8), object(1)
# memory usage: 3.5+ MB
#                        time  open_x  high_x   low_x  close_x  volume_x  \
# 0 2025-09-20 00:00:00+00:00  296.13  296.13  296.13   296.13       117
# 1 2025-09-20 00:01:00+00:00  296.13  296.13  296.13   296.13         1
# 2 2025-09-20 00:03:00+00:00  296.12  296.13  296.12   296.13        21
# 3 2025-09-20 00:04:00+00:00  296.13  296.13  296.13   296.13        53
# 4 2025-09-20 00:05:00+00:00  296.19  296.19  296.19   296.19         5
#
#     ret_1_x  ret_5_x   rng_1_x  vol_20_x  ...   ret_1_y  ret_5_y   rng_1_y  \
# 0       NaN      NaN       NaN       NaN  ...       NaN      NaN       NaN
# 1  0.000000      NaN  0.000000       NaN  ...  0.000000      NaN  0.000000
# 2  0.000000      NaN  0.000034       NaN  ...  0.000000      NaN  0.000034
# 3  0.000000      NaN  0.000000       NaN  ...  0.000000      NaN  0.000000
# 4  0.000203      NaN  0.000000       NaN  ...  0.000203      NaN  0.000000
#
#    vol_20_y   vwap_20_y  dist_vwap_y  is_open_30_y  is_close_30_y  ret_fwd_5  \
# 0       NaN         NaN          NaN             1              0   0.000203
# 1       NaN         NaN          NaN             1              0   0.000203
# 2       NaN         NaN          NaN             1              0   0.000203
# 3       NaN         NaN          NaN             1              0   0.000203
# 4       NaN  296.131168     0.000199             1              0  -0.000034
#
#    y_tb_20
# 0        0
# 1        0
# 2       -1
# 3       -1
# 4       -1
#
# [5 rows x 31 columns]

# %%
# только целевые столбцы
targets = [c for c in ml.columns if c.startswith("y_") or c.startswith("ret_fwd_")]
ml[targets].describe(include="all")

# баланс классов для triple-barrier
ml["y_tb_20"].value_counts(dropna=False)

# сохранить полный датасет
ml.to_parquet(os.path.join(FEATURES_OUT, "features_labeled_full.parquet"))

# %%
ml
# Out:
#                            time  open_x  high_x   low_x  close_x  volume_x  \
# 0     2025-09-20 00:00:00+00:00  296.13  296.13  296.13   296.13       117
# 1     2025-09-20 00:01:00+00:00  296.13  296.13  296.13   296.13         1
# 2     2025-09-20 00:03:00+00:00  296.12  296.13  296.12   296.13        21
# 3     2025-09-20 00:04:00+00:00  296.13  296.13  296.13   296.13        53
# 4     2025-09-20 00:05:00+00:00  296.19  296.19  296.19   296.19         5
# ...                         ...     ...     ...     ...      ...       ...
# 14830 2025-10-03 23:52:00+00:00  282.80  283.00  282.80   283.00      2530
# 14831 2025-10-03 23:53:00+00:00  283.00  283.00  282.99   282.99       115
# 14832 2025-10-03 23:54:00+00:00  282.99  282.99  282.99   282.99        11
# 14833 2025-10-03 23:56:00+00:00  282.22  282.22  282.21   282.21        83
# 14834 2025-10-03 23:58:00+00:00  282.22  282.22  282.22   282.22         2
#
#         ret_1_x   ret_5_x   rng_1_x  vol_20_x  ...   ret_1_y   ret_5_y  \
# 0           NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1      0.000000       NaN  0.000000       NaN  ...  0.000000       NaN
# 2      0.000000       NaN  0.000034       NaN  ...  0.000000       NaN
# 3      0.000000       NaN  0.000000       NaN  ...  0.000000       NaN
# 4      0.000203       NaN  0.000000       NaN  ...  0.000203       NaN
# ...         ...       ...       ...       ...  ...       ...       ...
# 14830  0.000742  0.000566  0.000707  0.001236  ...  0.000742  0.000566
# 14831 -0.000035  0.001910  0.000035  0.001227  ... -0.000035  0.001910
# 14832  0.000000  0.000566  0.000000  0.001215  ...  0.000000  0.000566
# 14833 -0.002760 -0.002053  0.000035  0.001302  ... -0.002760 -0.002053
# 14834  0.000035 -0.002018  0.000000  0.001301  ...  0.000035 -0.002018
#
#         rng_1_y  vol_20_y   vwap_20_y  dist_vwap_y  is_open_30_y  \
# 0           NaN       NaN         NaN          NaN             1
# 1      0.000000       NaN         NaN          NaN             1
# 2      0.000034       NaN         NaN          NaN             1
# 3      0.000000       NaN         NaN          NaN             1
# 4      0.000000       NaN  296.131168     0.000199             1
# ...         ...       ...         ...          ...           ...
# 14830  0.000707  0.001236  282.433803     0.002001             0
# 14831  0.000035  0.001227  282.438960     0.001947             0
# 14832  0.000000  0.001215  282.436074     0.001957             0
# 14833  0.000035  0.001302  282.434593    -0.000796             0
# 14834  0.000000  0.001301  282.434577    -0.000760             0
#
#        is_close_30_y  ret_fwd_5  y_tb_20
# 0                  0   0.000203        0
# 1                  0   0.000203        0
# 2                  0   0.000203       -1
# 3                  0   0.000203       -1
# 4                  0  -0.000034       -1
# ...              ...        ...      ...
# 14830              1   0.045352        0
# 14831              1   0.045387        0
# 14832              1   0.045387        0
# 14833              1   0.048147        0
# 14834              1   0.048314        0
#
# [14835 rows x 31 columns]

# %% [markdown]
# CV

# %%
import os
import glob
import pandas as pd

# ---- Параметры рендера (подставь свои при необходимости) ----
TICKER = "SBER"
TF     = "1m"
SIZE   = 64          # окно баров, с которым рендерили
STEP   = 16          # шаг окна при рендере

# ---- Пути согласно scripts/render_cv_images.py ----
IMAGES_DIR   = f"data/cv/images/{TICKER}/{TF}/win{SIZE}_step{STEP}"
MANIFEST_CSV = f"data/features/cv/{TICKER}/{TF}/manifest_win{SIZE}_step{STEP}.csv"

# 1) список изображений
imgs = sorted(glob.glob(os.path.join(IMAGES_DIR, "**", "*.png"), recursive=True))
print("images:", len(imgs))
print("sample:", imgs)

# 2) манифест (метаданные: time, путь, метка и т.д.)
cv_meta = None
if os.path.exists(MANIFEST_CSV):
    cv_meta = pd.read_csv(MANIFEST_CSV)
    print("manifest rows:", len(cv_meta))
    display(cv_meta.head())
else:
    print("manifest not found:", MANIFEST_CSV)

# 3) при необходимости — соединить с ML-фичами
# FEATURES_OUT = f"data/features/ml/{TICKER}/{TF}"
# feat_pq = sorted(glob.glob(os.path.join(FEATURES_OUT, "*.parquet")))[0]
# dfX = pd.read_parquet(feat_pq)
# df_full = cv_meta.merge(dfX, on="time", how="left") if cv_meta is not None else None
# display(df_full.head() if df_full is not None else "no merge performed")
# Out:
# images: 924
# sample: ['data/cv/images/SBER/1m/win64_step16\\flat\\img_0000000.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000001.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000002.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000003.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000004.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000005.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000006.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000007.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000008.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000009.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000010.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000011.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000012.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000013.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000014.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000015.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000016.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000017.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000018.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000019.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000020.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000021.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000022.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000023.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000024.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000025.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000026.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000027.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000028.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000029.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000030.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000031.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000032.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000033.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000034.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000035.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000036.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000037.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000038.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000039.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000040.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000041.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000042.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000043.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000044.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000045.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000046.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000047.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000048.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000049.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000050.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000051.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000052.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000053.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000054.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000055.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000056.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000057.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000058.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000059.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000060.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000061.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000062.png', 'data/cv/images/SBER/1m/win64_step16\\flat\\img_0000063.png', 'data/cv/images/SBER/1m ...
# manifest rows: 924
#                                                 path ticker  tf  \
# 0  data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 1  data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 2  data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 3  data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 4  data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
#
#                      t_start                      t_end  bars    ymin    ymax  \
# 0  2025-09-20 00:00:00+00:00  2025-09-20 01:10:00+00:00    64  293.12  296.39
# 1  2025-09-20 00:20:00+00:00  2025-09-20 01:26:00+00:00    64  293.12  296.39
# 2  2025-09-20 00:38:00+00:00  2025-09-20 01:43:00+00:00    64  293.23  294.64
# 3  2025-09-20 00:54:00+00:00  2025-09-20 02:00:00+00:00    64  293.32  294.24
# 4  2025-09-20 01:11:00+00:00  2025-09-20 02:17:00+00:00    64  293.32  294.61
#
#   vol_mode  vmin     vmax label
# 0      raw   1.0  40288.0  flat
# 1      raw   1.0  40288.0  flat
# 2      raw   1.0   7138.0  flat
# 3      raw   1.0   7138.0  flat
# 4      raw   1.0   7138.0  flat

# %%
cv_meta
# Out:
#                                                   path ticker  tf  \
# 0    data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 1    data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 2    data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 3    data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 4    data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# ..                                                 ...    ...  ..
# 919  data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 920  data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 921  data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 922  data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
# 923  data\cv\images\SBER\1m\win64_step16\flat\img_0...   SBER  1m
#
#                        t_start                      t_end  bars    ymin  \
# 0    2025-09-20 00:00:00+00:00  2025-09-20 01:10:00+00:00    64  293.12
# 1    2025-09-20 00:20:00+00:00  2025-09-20 01:26:00+00:00    64  293.12
# 2    2025-09-20 00:38:00+00:00  2025-09-20 01:43:00+00:00    64  293.23
# 3    2025-09-20 00:54:00+00:00  2025-09-20 02:00:00+00:00    64  293.32
# 4    2025-09-20 01:11:00+00:00  2025-09-20 02:17:00+00:00    64  293.32
# ..                         ...                        ...   ...     ...
# 919  2025-10-03 19:33:00+00:00  2025-10-03 20:36:00+00:00    64  282.82
# 920  2025-10-03 19:49:00+00:00  2025-10-03 23:02:00+00:00    64  281.00
# 921  2025-10-03 20:05:00+00:00  2025-10-03 23:18:00+00:00    64  281.00
# 922  2025-10-03 20:21:00+00:00  2025-10-03 23:37:00+00:00    64  281.00
# 923  2025-10-03 20:37:00+00:00  2025-10-03 23:53:00+00:00    64  281.00
#
#        ymax vol_mode   vmin      vmax label
# 0    296.39      raw    1.0   40288.0  flat
# 1    296.39      raw    1.0   40288.0  flat
# 2    294.64      raw    1.0    7138.0  flat
# 3    294.24      raw    1.0    7138.0  flat
# 4    294.61      raw    1.0    7138.0  flat
# ..      ...      ...    ...       ...   ...
# 919  283.50      raw  163.0  162658.0  flat
# 920  284.07      raw  111.0  162658.0  flat
# 921  284.07      raw    1.0   37535.0  flat
# 922  284.07      raw    1.0   37535.0  flat
# 923  284.07      raw    1.0   27951.0  flat
#
# [924 rows x 12 columns]

# %%
import pandas as pd, glob

for t in ["SBER","GAZP","LKOH","ROSN","GMKN"]:
    m = glob.glob(f"data/cv/images/{t}/1m/win64_step16/*/manifest_with_vol.csv")
    print(t, "classes:", m)
